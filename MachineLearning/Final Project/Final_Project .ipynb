# %% [markdown]
# You can find this ipynb also in github, on\
# https://github.com/Evanslearn/1st-Semester-AI-2023-2024-/tree/main/MachineLearning/Final%20Project

# %% [markdown]
# # Import Libraries

# %%
# Here we import the libraries we will use
import time
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neighbors import KNeighborsRegressor
import tensorflow as tf

def install_agent_libraries():
  # !pip install swig
  # !pip install gymnasium[box2d]
  # !pip install ray[rllib]
  # !pip install renderlab
#install_agent_libraries()

# %%
# Check if GPU is enabled
# !nvidia-smi -L
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
import imageio.v3 as iio
import glob
from skimage import color
from skimage.exposure import rescale_intensity
from skimage.transform import resize

# %% [markdown]
# # 1. Express the moves (rock, scissors, paper) into (0, 1, 2) respectively

# %%
label_names = ['rock', 'scissors', 'paper']

# %%
def return_image_labels(action, labels_length):

  if action == 'rock':
    label = 0
  if action == 'scissors':
    label = 1
  if action == 'paper':
    label = 2

  # We create our array, which will be either all 0s, 1s, or 2s
  labels = np.zeros(labels_length) + label

  return labels

# %%
# This function returns all images from a folder, in grayscale
def return_all_images_grayscale(folder):
  images = []

  # This is used to load the images
  for im_path in glob.glob(f"{folder}/*.png"):
    im = iio.imread(im_path)[:,:,:3] # We keep only the first 3 coordinates, so we throw away

    # Resize image, to reduce dimensionality (from (200, 300) to -> (20, 30) )
    im = resize(im, (dim1, dim2))

    # Convert images to grayscale, to reduce dimensionality
    im = color.rgb2gray(im)
    im = rescale_intensity(im, out_range=(0, 255))

    images.append(im)

  images = np.array(images)

  # If the folder is not called 'rock', 'paper', 'scissors, but 'rock_xxx', 'paper_xxx', 'scissors_xxx', handle it
  if folder not in ['rock','paper','scissors']:
    strings = folder.split('_')

    for string in strings:
      if string == 'rock':
        folder = 'rock'
      if string == 'paper':
        folder = 'paper'
      if string == 'scissors':
        folder = 'scissors'

  images_labels = return_image_labels(folder, len(images))

  return [images, images_labels]

# %%
dim1 = 20; dim2 = 30;

# %%
[images_rock, images_rock_labels] = return_all_images_grayscale('rock')
[images_scissors, images_scissors_labels] = return_all_images_grayscale('scissors')
[images_paper, images_paper_labels] = return_all_images_grayscale('paper')

# %% [markdown]
# # 2. Split the dataset into train-test: You can for each class select a ratio as test set (e.g. 20% of rock, 20% of scissors and 20% of paper) and use these to test your model/agent.

# %%
random_state = 0 # This is set to 0 (this way, we get the same results every time)
test_ratio = 0.2

# %%
# split into train and test sets
x_train_rock, x_test_rock, y_train_rock, y_test_rock = train_test_split(images_rock, images_rock_labels, test_size = test_ratio, random_state = random_state)
x_train_scissors, x_test_scissors, y_train_scissors, y_test_scissors = train_test_split(images_scissors, images_scissors_labels, test_size = test_ratio, random_state = random_state)
x_train_paper, x_test_paper, y_train_paper, y_test_paper = train_test_split(images_paper, images_paper_labels, test_size = test_ratio, random_state = random_state)

# %%
print(f'For sanity check, dimensions of \nall Rock images {images_rock.shape}, \ntrain set rock images {x_train_rock.shape}, \ntest set rock images: {x_test_rock.shape} ')
# Out:
# For sanity check, dimensions of
# all Rock images (726, 20, 30),
# train set rock images (580, 20, 30),
# test set rock images: (146, 20, 30)

# %%
# Create the x_train, x_test, y_train, y_test, by contatenating the respective arrays
x_train = np.concatenate((x_train_rock, x_train_scissors, x_train_paper))
x_test = np.concatenate((x_test_rock, x_test_scissors, x_test_paper))

y_train = np.concatenate((y_train_rock, y_train_scissors, y_train_paper))
y_test = np.concatenate((y_test_rock, y_test_scissors, y_test_paper))

# %%
print(f'For sanity check, dimensions of \ntrain Rock images {x_train_rock.shape}, \ntrain set scissors images {x_train_scissors.shape}, \ntest set paper images: {x_train_paper.shape} ')
print(f'\nDimensions of x_train: {x_train.shape}')
# Out:
# For sanity check, dimensions of
# train Rock images (580, 20, 30),
# train set scissors images (293, 20, 30),
# test set paper images: (569, 20, 30)
#
# Dimensions of x_train: (1442, 20, 30)

# %%
# We use the reshape method to do the flattening.
# We simply designate that the number of rows should remain the same, and -1 as second argument takes care of the other dimensions
x_train_flatten = x_train.reshape(x_train.shape[0], -1)
x_test_flatten = x_test.reshape(x_test.shape[0], -1)
print(f'x_train.shape = {x_train.shape}. x_train_flatten.shape = {x_train_flatten.shape}')
print(f'x_test.shape = {x_test.shape}. x_train_flatten.shape = {x_test_flatten.shape}')
# Out:
# x_train.shape = (1442, 20, 30). x_train_flatten.shape = (1442, 600)
# x_test.shape = (363, 20, 30). x_train_flatten.shape = (363, 600)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler() # Define our scaler

x_train_flatten_norm = scaler.fit_transform(x_train_flatten)
x_test_flatten_norm = scaler.transform(x_test_flatten)

# %%
# Convert y_train, y_test to one-hot encodings
num_classes = 3 # classes (0, 1, 2) -> (rock, scissors, paper)

y_train_tf = tf.one_hot(y_train, depth=num_classes)
y_test_tf = tf.one_hot(y_test, depth=num_classes)
y_train_tf.shape, y_test_tf.shape
# Out:
# (TensorShape([1442, 3]), TensorShape([363, 3]))

# %%
# Reshape our arrays, to make them appropriate for CNN in tensorflow
# We set dim1 and dim2, when resizing the images during data reading
x_train_cnn = np.reshape(x_train_flatten_norm, (x_train_flatten_norm.shape[0], dim1,dim2,1))
x_test_cnn = np.reshape(x_test_flatten_norm, (x_test_flatten_norm.shape[0], dim1,dim2,1))

cnn = tf.keras.Sequential(name='my-cnn')
cnn.add(tf.keras.layers.Input((dim1,dim2,1), name='input_layer'))

# %%
num_conv_layers = 2
num_filters = 64
kernel_size = (5,5)
strides = (1,1)
mlp_num_hidden_layers = 2
mlp_units_per_layer = 128
activation = 'relu'
dropout_rate = 0.4

# %%
# CNN
for i in range(num_conv_layers):
  cnn.add(
      tf.keras.layers.Conv2D(
          filters=num_filters,
          kernel_size=kernel_size,
          strides=strides,
          activation=activation,
          name=f'conv_layer{i+1}'
      )
  )
  cnn.add(tf.keras.layers.Dropout(rate=dropout_rate , name=f'dropout_{i+1}'))
  cnn.add(tf.keras.layers.MaxPooling2D(name=f'maxpool_{i+1}'))

# %%
# Flattening
cnn.add(tf.keras.layers.Flatten())

# %%
# MLP
for i in range(mlp_num_hidden_layers):
  cnn.add(tf.keras.layers.Dense(units=mlp_units_per_layer, name=f'hidden_layer_{i+1}'))
cnn.add(tf.keras.layers.Dense(units=num_classes, activation='softmax', name='output_layer'))
cnn.summary()
# Out:
# Model: "my-cnn"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv_layer1 (Conv2D)        (None, 16, 26, 64)        1664
#
#  dropout_1 (Dropout)         (None, 16, 26, 64)        0
#
#  maxpool_1 (MaxPooling2D)    (None, 8, 13, 64)         0
#
#  conv_layer2 (Conv2D)        (None, 4, 9, 64)          102464
#
#  dropout_2 (Dropout)         (None, 4, 9, 64)          0
#
#  maxpool_2 (MaxPooling2D)    (None, 2, 4, 64)          0
#
#  flatten (Flatten)           (None, 512)               0
#
#  hidden_layer_1 (Dense)      (None, 128)               65664
#
#  hidden_layer_2 (Dense)      (None, 128)               16512
#
#  output_layer (Dense)        (None, 3)                 387
#
# =================================================================
# Total params: 186691 (729.26 KB)
# Trainable params: 186691 (729.26 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
print(x_train_cnn.shape, y_train_tf.shape)
# Out:
# (1442, 20, 30, 1) (1442, 3)

# %%
learning_rate = 0.001
loss = 'categorical_crossentropy'
metrics = ['accuracy']
batch_size = 16 # Initially I had tried 32
epochs = 50


start_time = time.perf_counter() # Get current time at start

cnn.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate), loss=loss, metrics=metrics)
history = cnn.fit(x_train_cnn, y_train_tf, batch_size=batch_size, epochs=epochs)#, validation_data=(x_test_cnn, y_test_tf))

end_time = time.perf_counter() # Get current time at end
cnn_neural_time = end_time - start_time # Substract the time at start and time at end, to find the total run time
print(f"Training Time: {cnn_neural_time:.4f}")
# Out:
# Epoch 1/50
# 91/91 [==============================] - 2s 17ms/step - loss: 0.6800 - accuracy: 0.7011
# Epoch 2/50
# 91/91 [==============================] - 2s 20ms/step - loss: 0.1890 - accuracy: 0.9258
# Epoch 3/50
# 91/91 [==============================] - 2s 17ms/step - loss: 0.1309 - accuracy: 0.9563
# Epoch 4/50
# 91/91 [==============================] - 1s 16ms/step - loss: 0.1590 - accuracy: 0.9424
# Epoch 5/50
# 91/91 [==============================] - 1s 16ms/step - loss: 0.1170 - accuracy: 0.9584
# Epoch 6/50
# 91/91 [==============================] - 1s 16ms/step - loss: 0.0631 - accuracy: 0.9813
# Epoch 7/50
# 91/91 [==============================] - 1s 16ms/step - loss: 0.0624 - accuracy: 0.9799
# Epoch 8/50
# 91/91 [==============================] - 1s 16ms/step - loss: 0.0630 - accuracy: 0.9820
# Epoch 9/50
# 91/91 [==============================] - 2s 20ms/step - loss: 0.0782 - accuracy: 0.9681
# Epoch 10/50
# 91/91 [==============================] - 1s 16ms/step - loss: 0.0482 - accuracy: 0.9827
# Epoch 11/50
# 91/91 [==============================] - 1s 16ms/step - loss: 0.0370 - accuracy: 0.9854
# Epoch 12/50
# 91/91 [==============================] - 1s 16ms/step - loss: 0.0263 - accuracy: 0.9910
# Epoch 13/50
# 91/91 [==============================] - 1s 16ms/step - loss: 0.1452 - accuracy: 0.9563
# Epoch 14/50
# 91/91 [==============================] - 1s 16ms/step - loss: 0.0489 - accuracy: 0.9813
# Epoch 15/50
# 91/91 [==============================] - 1s 16ms/step - loss: 0.0363 - accuracy: 0.9889
# Epoch 16/50
# 91/91 [==============================] - 2s 19ms/step - loss: 0.0283 - accuracy: 0.9882
# Epoch 17/50
# 91/91 [==============================] - 2s 17ms/step - loss: 0.0434 - accuracy: 0.9847
# Epoch 18/50
# 91/91 [==============================] - 1s 16ms/step - loss: 0.0511 - accuracy: 0.9813
# Epoch 19/50
# 91/91 [==============================] - 1s 16ms/step - loss: 0.0534 - accuracy: 0.9840
# Epoch 20/50
# 91/91 [==============================] - 1s 16ms/step - loss: 0.0504 - accuracy: 0.9827
# Epoch 21/50
# 91/91 [==============================] - 1s 16ms/step - loss: 0.0273 - accuracy: 0.9945
# Epoch 22/50
# 91/91 [==============================] - 1s 16ms/step - loss: 0.0161 - accuracy: 0.9951
# Epoch 23/50
# 91/91 [==============================] - 2s 17ms/step - loss: 0.0168 - accuracy: 0.9938
# Epoch 24/50
# 91/91 [==============================] - 2s 19ms/step - loss: 0.0238 - accuracy: 0.9917
# Epoch 25/50
# 91/91 [==============================] - 1s 16ms/step - loss: 0.0371 - accuracy: 0.9847
# Epoch 26/50
# 91/91 [==============================] - 1s 16ms/step - loss: 0.0112 - accuracy: 0.9958
# Epoch 27/50
# 91/91 [==============================] - 1s 16ms/step - loss: 0.0295 - accuracy: 0.9903
# Epoch 28/50
# 91/91 [==============================] - 1s 16ms/step - loss: 0.0482 - accuracy: 0.9827
# Epoch 29/50
# 91/91 [==============================] - 1s 16ms/step - loss: 0.0339 - accuracy: 0.9875
# Epoch 30/50
# 91/91 [==============================] - 1s 16ms/step - loss: 0.0188 - accuracy: 0.9938
# Epoch 31/50
# 91/91 [==============================] - 2s 20ms/step - loss: 0.0572 - accuracy: 0.9834
# Epoch 32/50
# 91/91 [==============================] - 2s 17ms/step - loss: 0.0137 - accuracy: 0.9951
# Epoch 33/50
# 91/91 [==============================] - 1s 16ms/step - loss: 0.0155 - accuracy: 0.9945
# Epoch 34/50
# 91/91 [==============================] - 1s 16ms/step - loss: 0.0764 - accuracy: 0.9750
# Epoch 35/50
# 91/91 [==============================] - 1s 16ms/step - loss: 0.0668 - accuracy: 0.9827
# Epoch 36/50
# 91/91 [==============================] - 1s 16ms/step - loss: 0.0321 - accuracy: 0.9896
# Epoch 37/50
# 91/91 [==============================] - 1s 16ms/step - loss: 0.0258 - accuracy: 0.9910
# Epoch 38/50
# 91/91 [==============================] - 2s 20ms/step - loss: 0.0131 - accuracy: 0.9938
# Epoch 39/50
# 91/91 [==============================] - 1s 16ms/step - loss: 0.0088 - accuracy: 0.9979
# Epoch 40/50
# 91/91 [==============================] - 1s 16ms/step - loss: 0.0315 - accuracy: 0.9917
# Epoch 41/50
# 91/91 [==============================] - 1s 16ms/step - loss: 0.0067 - accuracy: 0.9972
# Epoch 42/50
# 91/91 [==============================] - 1s 16ms/step - loss: 0.0050 - accuracy: 0.9986
# Epoch 43/50
# 91/91 [==============================] - 2s 17ms/step - loss: 0.0054 - accuracy: 0.9972
# Epoch 44/50
# 91/91 [==============================] - 2s 18ms/step - loss: 0.0049 - accuracy: 0.9993
# Epoch 45/50
# 91/91 [==============================] - 3s 28ms/step - loss: 0.0093 - accuracy: 0.9958
# Epoch 46/50
# 91/91 [==============================] - 2s 20ms/step - loss: 0.0311 - accuracy: 0.9903
# Epoch 47/50
# 91/91 [==============================] - 1s 16ms/step - loss: 0.0161 - accuracy: 0.9965
# Epoch 48/50
# 91/91 [==============================] - 1s 16ms/step - loss: 0.0369 - accuracy: 0.9889
# Epoch 49/50
# 91/91 [==============================] - 1s 16ms/step - loss: 0.0285 - accuracy: 0.9910
# Epoch 50/50
# 91/91 [==============================] - 1s 16ms/step - loss: 0.0365 - accuracy: 0.9889
# Training Time: 82.8287

# %%
# From the training, we have the statistics stored in object history:
print(history.history.keys())

losses = history.history['loss']
accuracies = history.history['accuracy']
#val_losses = history.history['val_loss']
#val_accuracies = history.history['val_accuracy']
# Out:
# dict_keys(['loss', 'accuracy'])

# %%
# Plot the results of our training, for each epoch
f, axs = plt.subplots(1, 2, figsize=(10, 10))

plt.subplot(2,2,1)
plt.plot(losses)
plt.title('loss vs epoch')

plt.subplot(2,2,2)
plt.plot(accuracies)
plt.title('Accuracy vs epoch')

#plt.subplot(2,2,3)
#plt.plot(val_losses)
#plt.title('loss(val) vs epoch')

#plt.subplot(2,2,4)
#plt.plot(val_accuracies)
#plt.title('Accuracy(val) vs epoch')
# Out:
# <ipython-input-25-f3f8114bb9b4>:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(2,2,1)
# <ipython-input-25-f3f8114bb9b4>:8: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(2,2,2)
# Text(0.5, 1.0, 'Accuracy vs epoch')

# %%
cnn_test_loss, cnn_test_acc = cnn.evaluate(x_test_cnn, y_test_tf, verbose=2)
print('')
print(f'Our CNN has achieved a test accuracy of {cnn_test_acc*100:.2f}%')
# Out:
# 12/12 - 0s - loss: 0.1650 - accuracy: 0.9587 - 211ms/epoch - 18ms/step
#
# Our CNN has achieved a test accuracy of 95.87%

# %% [markdown]
# ## **Our CNN has achieved a test accuracy of accuracy: 97.52%**

# %% [markdown]
# # 3. Select Image: Select a radom image frm the 2100 (which corresponds to move 0, or 1, or 2)

# %%
import random

# %%
# since the method returns [a, b], I have set [1, length], and then deduct 1
random_integer = random.randint(1, len(x_test)) - 1

random_image = x_test[random_integer]
random_image_label = y_test[random_integer]
random_image_label_string = label_names[int(random_image_label)]

# %% [markdown]
# # 4. Preprocess Image: Process the image:

# %% [markdown]
# *  a. wih probability $p_1$ apply Vertical flip

# %%
import sys
np.set_printoptions(threshold=sys.maxsize)

# %%
def flip_vertically(image, p1 = 0.5):

  random_float = random.random()

  if random_float >= p1:
    image = np.flip(image, axis = 0) # We flip vertically

  return image

random_image = flip_vertically(random_image)

# %% [markdown]
# *  b. with probability $p_2$ apply Horizontal flip

# %%
def flip_horizontally(image, p2 = 0.5):

  random_float = random.random()

  if random_float >= p2:
    image = np.flip(image, axis = 1) # We flip horizontally

  return image

random_image = flip_horizontally(random_image)

# %% [markdown]
# *  c. Add noise with $\mu = 0$, $\sigma = 255\cdot 0.05$. If you normalize the image, adjust standard deviation accordingly.

# %%
def add_noise(image, mu = 0, sigma = 255 * 0.05):

  # if we have normalized, then normalize sigma as well
  if sigma == 255 * 0.05:
    if np.max(image) <= 1:
      sigma = sigma/255
  image = image + np.random.normal(mu, sigma, image.shape) # Add the gaussian noise
  return image

random_image = add_noise(random_image)

# %% [markdown]
# *  d. You can apply any other method Image Processing you want, so that you can make the game harder (if you want).

# %%
from scipy.ndimage import rotate

# %%
# I will also add a 45 degrees rotation, with probability 0.5
def rotate_angle(image, p3 = 0.5, angle = 45):

  random_float = random.random()

  if random_float >= p3:
    image = rotate(image, angle=45, reshape=False)
  return image

random_image = rotate_angle(random_image)

# %% [markdown]
# # 5. Apply: Send the image to your agent

# %%
# COnvert the image to tf tensor
img_array = tf.keras.utils.img_to_array(random_image)
img_array = tf.expand_dims(img_array, 0) # Create a batch

# Calculate predictions
predictions = cnn.predict(img_array)
score = tf.nn.softmax(predictions[0])
predicted_enemy_action = label_names[np.argmax(predictions[0])]

print(
    "This image most likely belongs to {} = {} with a {:.2f} percent confidence."
    .format(np.argmax(predictions[0]), predicted_enemy_action, 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 0s 80ms/step
# This image most likely belongs to 0 = rock with a 57.61 percent confidence.

# %% [markdown]
# # 6. The agent reads the image and selects the optimal action

# %%
def select_optimal_action(enemy_action):

  if enemy_action == 'rock':
    optimal_action = 'paper'
  if enemy_action == 'scissors':
    optimal_action = 'rock'
  if enemy_action == 'paper':
    optimal_action = 'scissors'

  return optimal_action

# %%
optimal_action = select_optimal_action(enemy_action = predicted_enemy_action)
print("Enemy predicted action \n\t{} \nso our model played \n\t{}".format(predicted_enemy_action, optimal_action))
# Out:
# Enemy predicted action
# 	rock
# so our model played
# 	paper

# %% [markdown]
# # 7. The goal is maximizing gain. So, you will need to plot the agent's gain (You can store the total gain for every round and plot it at the end of the game)

# %%
def return_gain_step(predicted_enemy_action, actual_enemy_action):

  # If we predicted the enemy action correctly, then we win since we play 2nd. Gain for win is 2
  if predicted_enemy_action == actual_enemy_action:
    gain = 2
  else:
    # If we played the same as the enemy, then it's a draw. Gain for draw is 1
    if( select_optimal_action(predicted_enemy_action) == actual_enemy_action ):
      gain = 1
    else:
      gain = 0

  return gain

# %%
gain_for_one_step = return_gain_step(predicted_enemy_action = predicted_enemy_action, actual_enemy_action = random_image_label_string)
print(
    "The model played one round. \nactual_enemy_action = {}. \npredicted_enemy_action = {}. \nSo, the gain is = {}"
    .format(predicted_enemy_action, random_image_label_string, gain_for_one_step)
)
# Out:
# The model played one round.
# actual_enemy_action = rock.
# predicted_enemy_action = paper.
# So, the gain is = 1

# %%
# i will now try calculating the total gain for the whole test set
N = len(x_test)

gain_total = np.zeros(N)
gain_cum = np.zeros(N)
index_help = range(0,N)

for i in range(0, N):
  print(f'i = {i}')

  # get image from test set
  random_image = x_test[i]
  random_image_label = y_test[i]
  random_image_label_string = label_names[int(random_image_label)]

  # apply preprocessing to the image
  random_image = flip_vertically(random_image)
  random_image = flip_horizontally(random_image)
  random_image = add_noise(random_image)
  random_image = rotate_angle(random_image)

  # Convert image to tf array
  img_array = tf.keras.utils.img_to_array(random_image)
  img_array = tf.expand_dims(img_array, 0)

  # Calculate predictions
  predictions = cnn.predict(img_array)
  predicted_enemy_action = label_names[np.argmax(predictions[0])]

  gain_for_one_step = return_gain_step(predicted_enemy_action = predicted_enemy_action, actual_enemy_action = random_image_label_string)
  if i >=1:
    gain_cum[i] = gain_cum[i-1] + gain_for_one_step
  gain_total[i] = gain_for_one_step
# Out:
# i = 0
# 1/1 [==============================] - 0s 15ms/step
# i = 1
# 1/1 [==============================] - 0s 15ms/step
# i = 2
# 1/1 [==============================] - 0s 15ms/step
# i = 3
# 1/1 [==============================] - 0s 16ms/step
# i = 4
# 1/1 [==============================] - 0s 16ms/step
# i = 5
# 1/1 [==============================] - 0s 16ms/step
# i = 6
# 1/1 [==============================] - 0s 20ms/step
# i = 7
# 1/1 [==============================] - 0s 16ms/step
# i = 8
# 1/1 [==============================] - 0s 20ms/step
# i = 9
# 1/1 [==============================] - 0s 17ms/step
# i = 10
# 1/1 [==============================] - 0s 18ms/step
# i = 11
# 1/1 [==============================] - 0s 14ms/step
# i = 12
# 1/1 [==============================] - 0s 15ms/step
# i = 13
# 1/1 [==============================] - 0s 16ms/step
# i = 14
# 1/1 [==============================] - 0s 18ms/step
# i = 15
# 1/1 [==============================] - 0s 15ms/step
# i = 16
# 1/1 [==============================] - 0s 14ms/step
# i = 17
# 1/1 [==============================] - 0s 17ms/step
# i = 18
# 1/1 [==============================] - 0s 15ms/step
# i = 19
# 1/1 [==============================] - 0s 16ms/step
# i = 20
# 1/1 [==============================] - 0s 16ms/step
# i = 21
# 1/1 [==============================] - 0s 17ms/step
# i = 22
# 1/1 [==============================] - 0s 16ms/step
# i = 23
# 1/1 [==============================] - 0s 18ms/step
# i = 24
# 1/1 [==============================] - 0s 15ms/step
# i = 25
# 1/1 [==============================] - 0s 15ms/step
# i = 26
# 1/1 [==============================] - 0s 15ms/step
# i = 27
# 1/1 [==============================] - 0s 14ms/step
# i = 28
# 1/1 [==============================] - 0s 16ms/step
# i = 29
# 1/1 [==============================] - 0s 14ms/step
# i = 30
# 1/1 [==============================] - 0s 15ms/step
# i = 31
# 1/1 [==============================] - 0s 15ms/step
# i = 32
# 1/1 [==============================] - 0s 14ms/step
# i = 33
# 1/1 [==============================] - 0s 14ms/step
# i = 34
# 1/1 [==============================] - 0s 15ms/step
# i = 35
# 1/1 [==============================] - 0s 15ms/step
# i = 36
# 1/1 [==============================] - 0s 15ms/step
# i = 37
# 1/1 [==============================] - 0s 15ms/step
# i = 38
# 1/1 [==============================] - 0s 15ms/step
# i = 39
# 1/1 [==============================] - 0s 14ms/step
# i = 40
# 1/1 [==============================] - 0s 17ms/step
# i = 41
# 1/1 [==============================] - 0s 15ms/step
# i = 42
# 1/1 [==============================] - 0s 18ms/step
# i = 43
# 1/1 [==============================] - 0s 17ms/step
# i = 44
# 1/1 [==============================] - 0s 16ms/step
# i = 45
# 1/1 [==============================] - 0s 14ms/step
# i = 46
# 1/1 [==============================] - 0s 17ms/step
# i = 47
# 1/1 [==============================] - 0s 15ms/step
# i = 48
# 1/1 [==============================] - 0s 24ms/step
# i = 49
# 1/1 [==============================] - 0s 15ms/step
# i = 50
# 1/1 [==============================] - 0s 16ms/step
# i = 51
# 1/1 [==============================] - 0s 15ms/step
# i = 52
# 1/1 [==============================] - 0s 16ms/step
# i = 53
# 1/1 [==============================] - 0s 16ms/step
# i = 54
# 1/1 [==============================] - 0s 14ms/step
# i = 55
# 1/1 [==============================] - 0s 14ms/step
# i = 56
# 1/1 [==============================] - 0s 16ms/step
# i = 57
# 1/1 [==============================] - 0s 19ms/step
# i = 58
# 1/1 [==============================] - 0s 15ms/step
# i = 59
# 1/1 [==============================] - 0s 19ms/step
# i = 60
# 1/1 [==============================] - 0s 18ms/step
# i = 61
# 1/1 [==============================] - 0s 14ms/step
# i = 62
# 1/1 [==============================] - 0s 15ms/step
# i = 63
# 1/1 [==============================] - 0s 15ms/step
# i = 64
# 1/1 [==============================] - 0s 14ms/step
# i = 65
# 1/1 [==============================] - 0s 20ms/step
# i = 66
# 1/1 [==============================] - 0s 15ms/step
# i = 67
# 1/1 [==============================] - 0s 14ms/step
# i = 68
# 1/1 [==============================] - 0s 15ms/step
# i = 69
# 1/1 [==============================] - 0s 15ms/step
# i = 70
# 1/1 [==============================] - 0s 15ms/step
# i = 71
# 1/1 [==============================] - 0s 15ms/step
# i = 72
# 1/1 [==============================] - 0s 16ms/step
# i = 73
# 1/1 [==============================] - 0s 17ms/step
# i = 74
# 1/1 [==============================] - 0s 18ms/step
# i = 75
# 1/1 [==============================] - 0s 15ms/step
# i = 76
# 1/1 [==============================] - 0s 16ms/step
# i = 77
# 1/1 [==============================] - 0s 15ms/step
# i = 78
# 1/1 [==============================] - 0s 15ms/step
# i = 79
# 1/1 [==============================] - 0s 15ms/step
# i = 80
# 1/1 [==============================] - 0s 15ms/step
# i = 81
# 1/1 [==============================] - 0s 15ms/step
# i = 82
# 1/1 [==============================] - 0s 24ms/step
# i = 83
# 1/1 [==============================] - 0s 14ms/step
# i = 84
# 1/1 [==============================] - 0s 16ms/step
# i = 85
# 1/1 [==============================] - 0s 14ms/step
# i = 86
# 1/1 [==============================] - 0s 14ms/step
# i = 87
# 1/1 [==============================] - 0s 15ms/step
# i = 88
# 1/1 [==============================] - 0s 15ms/step
# i = 89
# 1/1 [==============================] - 0s 16ms/step
# i = 90
# 1/1 [==============================] - 0s 15ms/step
# i = 91
# 1/1 [==============================] - 0s 15ms/step
# i = 92
# 1/1 [==============================] - 0s 15ms/step
# i = 93
# 1/1 [==============================] - 0s 16ms/step
# i = 94
# 1/1 [==============================] - 0s 15ms/step
# i = 95
# 1/1 [==============================] - 0s 14ms/step
# i = 96
# 1/1 [==============================] - 0s 16ms/step
# i = 97
# 1/1 [==============================] - 0s 16ms/step
# i = 98
# 1/1 [==============================] - 0s 16ms/step
# i = 99
# 1/1 [==============================] - 0s 24ms/step
# i = 100
# 1/1 [==============================] - 0s 15ms/step
# i = 101
# 1/1 [==============================] - 0s 16ms/step
# i = 102
# 1/1 [==============================] - 0s 16ms/step
# i = 103
# 1/1 [==============================] - 0s 14ms/step
# i = 104
# 1/1 [==============================] - 0s 15ms/step
# i = 105
# 1/1 [==============================] - 0s 15ms/step
# i = 106
# 1/1 [==============================] - 0s 16ms/step
# i = 107
# 1/1 [==============================] - 0s 16ms/step
# i = 108
# 1/1 [==============================] - 0s 20ms/step
# i = 109
# 1/1 [==============================] - 0s 15ms/step
# i = 110
# 1/1 [==============================] - 0s 15ms/step
# i = 111
# 1/1 [==============================] - 0s 15ms/step
# i = 112
# 1/1 [==============================] - 0s 15ms/step
# i = 113
# 1/1 [==============================] - 0s 15ms/step
# i = 114
# 1/1 [==============================] - 0s 16ms/step
# i = 115
# 1/1 [==============================] - 0s 15ms/step
# i = 116
# 1/1 [==============================] - 0s 22ms/step
# i = 117
# 1/1 [==============================] - 0s 14ms/step
# i = 118
# 1/1 [==============================] - 0s 18ms/step
# i = 119
# 1/1 [==============================] - 0s 17ms/step
# i = 120
# 1/1 [==============================] - 0s 25ms/step
# i = 121
# 1/1 [==============================] - 0s 23ms/step
# i = 122
# 1/1 [==============================] - 0s 22ms/step
# i = 123
# 1/1 [==============================] - 0s 20ms/step
# i = 124
# 1/1 [==============================] - 0s 20ms/step
# i = 125
# 1/1 [==============================] - 0s 20ms/step
# i = 126
# 1/1 [==============================] - 0s 23ms/step
# i = 127
# 1/1 [==============================] - 0s 24ms/step
# i = 128
# 1/1 [==============================] - 0s 22ms/step
# i = 129
# 1/1 [==============================] - 0s 19ms/step
# i = 130
# 1/1 [==============================] - 0s 23ms/step
# i = 131
# 1/1 [==============================] - 0s 19ms/step
# i = 132
# 1/1 [==============================] - 0s 15ms/step
# i = 133
# 1/1 [==============================] - 0s 17ms/step
# i = 134
# 1/1 [==============================] - 0s 17ms/step
# i = 135
# 1/1 [==============================] - 0s 14ms/step
# i = 136
# 1/1 [==============================] - 0s 14ms/step
# i = 137
# 1/1 [==============================] - 0s 14ms/step
# i = 138
# 1/1 [==============================] - 0s 16ms/step
# i = 139
# 1/1 [==============================] - 0s 21ms/step
# i = 140
# 1/1 [==============================] - 0s 14ms/step
# i = 141
# 1/1 [==============================] - 0s 19ms/step
# i = 142
# 1/1 [==============================] - 0s 16ms/step
# i = 143
# 1/1 [==============================] - 0s 16ms/step
# i = 144
# 1/1 [==============================] - 0s 20ms/step
# i = 145
# 1/1 [==============================] - 0s 17ms/step
# i = 146
# 1/1 [==============================] - 0s 16ms/step
# i = 147
# 1/1 [==============================] - 0s 16ms/step
# i = 148
# 1/1 [==============================] - 0s 18ms/step
# i = 149
# 1/1 [==============================] - 0s 16ms/step
# i = 150
# 1/1 [==============================] - 0s 16ms/step
# i = 151
# 1/1 [==============================] - 0s 16ms/step
# i = 152
# 1/1 [==============================] - 0s 19ms/step
# i = 153
# 1/1 [==============================] - 0s 16ms/step
# i = 154
# 1/1 [==============================] - 0s 15ms/step
# i = 155
# 1/1 [==============================] - 0s 18ms/step
# i = 156
# 1/1 [==============================] - 0s 15ms/step
# i = 157
# 1/1 [==============================] - 0s 16ms/step
# i = 158
# 1/1 [==============================] - 0s 16ms/step
# i = 159
# 1/1 [==============================] - 0s 15ms/step
# i = 160
# 1/1 [==============================] - 0s 15ms/step
# i = 161
# 1/1 [==============================] - 0s 15ms/step
# i = 162
# 1/1 [==============================] - 0s 16ms/step
# i = 163
# 1/1 [==============================] - 0s 17ms/step
# i = 164
# 1/1 [==============================] - 0s 15ms/step
# i = 165
# 1/1 [==============================] - 0s 16ms/step
# i = 166
# 1/1 [==============================] - 0s 15ms/step
# i = 167
# 1/1 [==============================] - 0s 16ms/step
# i = 168
# 1/1 [==============================] - 0s 17ms/step
# i = 169
# 1/1 [==============================] - 0s 20ms/step
# i = 170
# 1/1 [==============================] - 0s 15ms/step
# i = 171
# 1/1 [==============================] - 0s 16ms/step
# i = 172
# 1/1 [==============================] - 0s 15ms/step
# i = 173
# 1/1 [==============================] - 0s 15ms/step
# i = 174
# 1/1 [==============================] - 0s 15ms/step
# i = 175
# 1/1 [==============================] - 0s 17ms/step
# i = 176
# 1/1 [==============================] - 0s 15ms/step
# i = 177
# 1/1 [==============================] - 0s 16ms/step
# i = 178
# 1/1 [==============================] - 0s 14ms/step
# i = 179
# 1/1 [==============================] - 0s 18ms/step
# i = 180
# 1/1 [==============================] - 0s 17ms/step
# i = 181
# 1/1 [==============================] - 0s 15ms/step
# i = 182
# 1/1 [==============================] - 0s 16ms/step
# i = 183
# 1/1 [==============================] - 0s 17ms/step
# i = 184
# 1/1 [==============================] - 0s 16ms/step
# i = 185
# 1/1 [==============================] - 0s 19ms/step
# i = 186
# 1/1 [==============================] - 0s 16ms/step
# i = 187
# 1/1 [==============================] - 0s 18ms/step
# i = 188
# 1/1 [==============================] - 0s 15ms/step
# i = 189
# 1/1 [==============================] - 0s 14ms/step
# i = 190
# 1/1 [==============================] - 0s 15ms/step
# i = 191
# 1/1 [==============================] - 0s 15ms/step
# i = 192
# 1/1 [==============================] - 0s 15ms/step
# i = 193
# 1/1 [==============================] - 0s 21ms/step
# i = 194
# 1/1 [==============================] - 0s 14ms/step
# i = 195
# 1/1 [==============================] - 0s 21ms/step
# i = 196
# 1/1 [==============================] - 0s 15ms/step
# i = 197
# 1/1 [==============================] - 0s 14ms/step
# i = 198
# 1/1 [==============================] - 0s 14ms/step
# i = 199
# 1/1 [==============================] - 0s 15ms/step
# i = 200
# 1/1 [==============================] - 0s 17ms/step
# i = 201
# 1/1 [==============================] - 0s 19ms/step
# i = 202
# 1/1 [==============================] - 0s 15ms/step
# i = 203
# 1/1 [==============================] - 0s 17ms/step
# i = 204
# 1/1 [==============================] - 0s 15ms/step
# i = 205
# 1/1 [==============================] - 0s 14ms/step
# i = 206
# 1/1 [==============================] - 0s 15ms/step
# i = 207
# 1/1 [==============================] - 0s 17ms/step
# i = 208
# 1/1 [==============================] - 0s 15ms/step
# i = 209
# 1/1 [==============================] - 0s 17ms/step
# i = 210
# 1/1 [==============================] - 0s 14ms/step
# i = 211
# 1/1 [==============================] - 0s 15ms/step
# i = 212
# 1/1 [==============================] - 0s 15ms/step
# i = 213
# 1/1 [==============================] - 0s 17ms/step
# i = 214
# 1/1 [==============================] - 0s 16ms/step
# i = 215
# 1/1 [==============================] - 0s 16ms/step
# i = 216
# 1/1 [==============================] - 0s 14ms/step
# i = 217
# 1/1 [==============================] - 0s 15ms/step
# i = 218
# 1/1 [==============================] - 0s 15ms/step
# i = 219
# 1/1 [==============================] - 0s 15ms/step
# i = 220
# 1/1 [==============================] - 0s 17ms/step
# i = 221
# 1/1 [==============================] - 0s 15ms/step
# i = 222
# 1/1 [==============================] - 0s 16ms/step
# i = 223
# 1/1 [==============================] - 0s 15ms/step
# i = 224
# 1/1 [==============================] - 0s 17ms/step
# i = 225
# 1/1 [==============================] - 0s 14ms/step
# i = 226
# 1/1 [==============================] - 0s 14ms/step
# i = 227
# 1/1 [==============================] - 0s 15ms/step
# i = 228
# 1/1 [==============================] - 0s 17ms/step
# i = 229
# 1/1 [==============================] - 0s 16ms/step
# i = 230
# 1/1 [==============================] - 0s 16ms/step
# i = 231
# 1/1 [==============================] - 0s 16ms/step
# i = 232
# 1/1 [==============================] - 0s 16ms/step
# i = 233
# 1/1 [==============================] - 0s 17ms/step
# i = 234
# 1/1 [==============================] - 0s 15ms/step
# i = 235
# 1/1 [==============================] - 0s 15ms/step
# i = 236
# 1/1 [==============================] - 0s 19ms/step
# i = 237
# 1/1 [==============================] - 0s 16ms/step
# i = 238
# 1/1 [==============================] - 0s 16ms/step
# i = 239
# 1/1 [==============================] - 0s 15ms/step
# i = 240
# 1/1 [==============================] - 0s 17ms/step
# i = 241
# 1/1 [==============================] - 0s 16ms/step
# i = 242
# 1/1 [==============================] - 0s 16ms/step
# i = 243
# 1/1 [==============================] - 0s 16ms/step
# i = 244
# 1/1 [==============================] - 0s 16ms/step
# i = 245
# 1/1 [==============================] - 0s 19ms/step
# i = 246
# 1/1 [==============================] - 0s 19ms/step
# i = 247
# 1/1 [==============================] - 0s 16ms/step
# i = 248
# 1/1 [==============================] - 0s 17ms/step
# i = 249
# 1/1 [==============================] - 0s 15ms/step
# i = 250
# 1/1 [==============================] - 0s 17ms/step
# i = 251
# 1/1 [==============================] - 0s 15ms/step
# i = 252
# 1/1 [==============================] - 0s 17ms/step
# i = 253
# 1/1 [==============================] - 0s 16ms/step
# i = 254
# 1/1 [==============================] - 0s 16ms/step
# i = 255
# 1/1 [==============================] - 0s 17ms/step
# i = 256
# 1/1 [==============================] - 0s 18ms/step
# i = 257
# 1/1 [==============================] - 0s 16ms/step
# i = 258
# 1/1 [==============================] - 0s 21ms/step
# i = 259
# 1/1 [==============================] - 0s 14ms/step
# i = 260
# 1/1 [==============================] - 0s 17ms/step
# i = 261
# 1/1 [==============================] - 0s 15ms/step
# i = 262
# 1/1 [==============================] - 0s 17ms/step
# i = 263
# 1/1 [==============================] - 0s 15ms/step
# i = 264
# 1/1 [==============================] - 0s 15ms/step
# i = 265
# 1/1 [==============================] - 0s 14ms/step
# i = 266
# 1/1 [==============================] - 0s 16ms/step
# i = 267
# 1/1 [==============================] - 0s 15ms/step
# i = 268
# 1/1 [==============================] - 0s 16ms/step
# i = 269
# 1/1 [==============================] - 0s 18ms/step
# i = 270
# 1/1 [==============================] - 0s 15ms/step
# i = 271
# 1/1 [==============================] - 0s 15ms/step
# i = 272
# 1/1 [==============================] - 0s 15ms/step
# i = 273
# 1/1 [==============================] - 0s 15ms/step
# i = 274
# 1/1 [==============================] - 0s 17ms/step
# i = 275
# 1/1 [==============================] - 0s 16ms/step
# i = 276
# 1/1 [==============================] - 0s 15ms/step
# i = 277
# 1/1 [==============================] - 0s 17ms/step
# i = 278
# 1/1 [==============================] - 0s 21ms/step
# i = 279
# 1/1 [==============================] - 0s 15ms/step
# i = 280
# 1/1 [==============================] - 0s 15ms/step
# i = 281
# 1/1 [==============================] - 0s 16ms/step
# i = 282
# 1/1 [==============================] - 0s 15ms/step
# i = 283
# 1/1 [==============================] - 0s 16ms/step
# i = 284
# 1/1 [==============================] - 0s 15ms/step
# i = 285
# 1/1 [==============================] - 0s 15ms/step
# i = 286
# 1/1 [==============================] - 0s 15ms/step
# i = 287
# 1/1 [==============================] - 0s 18ms/step
# i = 288
# 1/1 [==============================] - 0s 16ms/step
# i = 289
# 1/1 [==============================] - 0s 16ms/step
# i = 290
# 1/1 [==============================] - 0s 16ms/step
# i = 291
# 1/1 [==============================] - 0s 15ms/step
# i = 292
# 1/1 [==============================] - 0s 16ms/step
# i = 293
# 1/1 [==============================] - 0s 15ms/step
# i = 294
# 1/1 [==============================] - 0s 15ms/step
# i = 295
# 1/1 [==============================] - 0s 32ms/step
# i = 296
# 1/1 [==============================] - 0s 23ms/step
# i = 297
# 1/1 [==============================] - 0s 20ms/step
# i = 298
# 1/1 [==============================] - 0s 21ms/step
# i = 299
# 1/1 [==============================] - 0s 19ms/step
# i = 300
# 1/1 [==============================] - 0s 20ms/step
# i = 301
# 1/1 [==============================] - 0s 20ms/step
# i = 302
# 1/1 [==============================] - 0s 23ms/step
# i = 303
# 1/1 [==============================] - 0s 24ms/step
# i = 304
# 1/1 [==============================] - 0s 22ms/step
# i = 305
# 1/1 [==============================] - 0s 28ms/step
# i = 306
# 1/1 [==============================] - 0s 26ms/step
# i = 307
# 1/1 [==============================] - 0s 15ms/step
# i = 308
# 1/1 [==============================] - 0s 23ms/step
# i = 309
# 1/1 [==============================] - 0s 17ms/step
# i = 310
# 1/1 [==============================] - 0s 15ms/step
# i = 311
# 1/1 [==============================] - 0s 16ms/step
# i = 312
# 1/1 [==============================] - 0s 17ms/step
# i = 313
# 1/1 [==============================] - 0s 17ms/step
# i = 314
# 1/1 [==============================] - 0s 16ms/step
# i = 315
# 1/1 [==============================] - 0s 14ms/step
# i = 316
# 1/1 [==============================] - 0s 14ms/step
# i = 317
# 1/1 [==============================] - 0s 15ms/step
# i = 318
# 1/1 [==============================] - 0s 16ms/step
# i = 319
# 1/1 [==============================] - 0s 19ms/step
# i = 320
# 1/1 [==============================] - 0s 16ms/step
# i = 321
# 1/1 [==============================] - 0s 17ms/step
# i = 322
# 1/1 [==============================] - 0s 16ms/step
# i = 323
# 1/1 [==============================] - 0s 17ms/step
# i = 324
# 1/1 [==============================] - 0s 17ms/step
# i = 325
# 1/1 [==============================] - 0s 16ms/step
# i = 326
# 1/1 [==============================] - 0s 16ms/step
# i = 327
# 1/1 [==============================] - 0s 15ms/step
# i = 328
# 1/1 [==============================] - 0s 18ms/step
# i = 329
# 1/1 [==============================] - 0s 18ms/step
# i = 330
# 1/1 [==============================] - 0s 16ms/step
# i = 331
# 1/1 [==============================] - 0s 15ms/step
# i = 332
# 1/1 [==============================] - 0s 15ms/step
# i = 333
# 1/1 [==============================] - 0s 14ms/step
# i = 334
# 1/1 [==============================] - 0s 14ms/step
# i = 335
# 1/1 [==============================] - 0s 14ms/step
# i = 336
# 1/1 [==============================] - 0s 14ms/step
# i = 337
# 1/1 [==============================] - 0s 16ms/step
# i = 338
# 1/1 [==============================] - 0s 15ms/step
# i = 339
# 1/1 [==============================] - 0s 14ms/step
# i = 340
# 1/1 [==============================] - 0s 15ms/step
# i = 341
# 1/1 [==============================] - 0s 15ms/step
# i = 342
# 1/1 [==============================] - 0s 21ms/step
# i = 343
# 1/1 [==============================] - 0s 17ms/step
# i = 344
# 1/1 [==============================] - 0s 14ms/step
# i = 345
# 1/1 [==============================] - 0s 17ms/step
# i = 346
# 1/1 [==============================] - 0s 14ms/step
# i = 347
# 1/1 [==============================] - 0s 15ms/step
# i = 348
# 1/1 [==============================] - 0s 16ms/step
# i = 349
# 1/1 [==============================] - 0s 16ms/step
# i = 350
# 1/1 [==============================] - 0s 15ms/step
# i = 351
# 1/1 [==============================] - 0s 16ms/step
# i = 352
# 1/1 [==============================] - 0s 17ms/step
# i = 353
# 1/1 [==============================] - 0s 15ms/step
# i = 354
# 1/1 [==============================] - 0s 16ms/step
# i = 355
# 1/1 [==============================] - 0s 15ms/step
# i = 356
# 1/1 [==============================] - 0s 18ms/step
# i = 357
# 1/1 [==============================] - 0s 15ms/step
# i = 358
# 1/1 [==============================] - 0s 15ms/step
# i = 359
# 1/1 [==============================] - 0s 15ms/step
# i = 360
# 1/1 [==============================] - 0s 14ms/step
# i = 361
# 1/1 [==============================] - 0s 14ms/step
# i = 362
# 1/1 [==============================] - 0s 15ms/step

# %%
plt.plot(index_help, gain_cum)
plt.xlabel('Ascending Number (Sample index)')
plt.ylabel('Cumulative Gain')
plt.title('Cumulative gain vs Sample Index')
# Out:
# Text(0.5, 1.0, 'Cumulative gain vs Sample Index')

# %%
# As accuracy, I will define how many time the agent won (so gain is 2), over how many times the agent played
unique, counts = np.unique(gain_total, return_counts=True)
print(f'The unique values are: {unique}')
print(f'The count values are:  {counts}')
print(f'Accuracy is counts[2]/sum(counts) * 100% = {counts[2]/sum(counts)*100:.2f}%')
# Out:
# The unique values are: [0. 1. 2.]
# The count values are:  [ 52  86 225]
# Accuracy is counts[2]/sum(counts) * 100% = 61.98%

# %% [markdown]
# ## Results for our model, when we apply all preprocessing steps in the test set:

# %% [markdown]
# * The unique values are: [0. 1. 2.]
# * The count values are:  [ 68  85 257]
# * Accuracy is counts[2]/sum(counts) * 100% = 62.68%
#
# These results are not encouraging, and from the cumulative gain plot, we understand that we do not have many fluctuations (approximately a linear plot), so accuracy should be a stable estimate for our test set.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# I tried also without the 4th pre-processing step (the image rotation), and the results are:
# * The unique values are: [0. 1. 2.]
# * The count values are:  [ 56  34 320]
# * Accuracy is counts[2]/sum(counts) * 100% = 78.05%
# So, accuracy has increased, but 78% does not seem that good to me

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# I tried, using only the add-noise pre-processing step, and these are the results:
# * The unique values are: [0. 1. 2.]
# * The count values are:  [  9   7 394]
# * Accuracy is counts[2]/sum(counts) * 100% = 96.10%

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# I also tried, without any pre-processing, and these are the results:
# * The unique values are: [0. 1. 2.]
# * The count values are:  [ 19   7 384]
# * Accuracy is counts[2]/sum(counts) * 100% = 93.66%

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 8. As end goal, try the accuracy of the agent (or model) on images outside of the dataset, e.g. from the internet or your own, which you must rescale to the same size. For example, you can try the action it will output for the attached image

# %% [markdown]
# I test with the dataset from https://www.kaggle.com/datasets/glushko/rock-paper-scissors-dataset, which shows both a human face and an action (rock, paper, scissors) in the picture, to see how my model would do.

# %%
dim1 = 20; dim2 = 30;

# %%
[images_rock_test, images_rock_labels_test] = return_all_images_grayscale('rock_test')
[images_scissors_test, images_scissors_labels_test] = return_all_images_grayscale('scissors_test')
[images_paper_test, images_paper_labels_test] = return_all_images_grayscale('paper_test')

# %%
# Create the x_test, y_test, by contatenating the respective arrays

x_test_test = np.concatenate((images_rock_test, images_scissors_test, images_paper_test))
y_test_test = np.concatenate((images_rock_labels_test, images_scissors_labels_test, images_paper_labels_test))

# %%
# We use the reshape method to do the flattening.
# We simply designate that the number of rows should remain the same, and -1 as second argument takes care of the other dimensions
x_test_test_flatten = x_test_test.reshape(x_test_test.shape[0],-1)
print(f'x_test.shape = {x_test_test.shape}. x_train_flatten.shape = {x_test_test_flatten.shape}')
# Out:
# x_test.shape = (540, 20, 30). x_train_flatten.shape = (540, 600)

# %%
# Normalize by dividing with 255
x_test_test_flatten_norm = x_test_test_flatten/255

# %%
# Convert y_train, y_test to one-hot encodings
num_classes = 3 # classes (0, 1, 2) -> (rock, scissors, paper)

y_test_test_tf = tf.one_hot(y_test_test, depth=num_classes)
y_test_test_tf.shape
# Out:
# TensorShape([540, 3])

# %%
# i will now try calculating the total gain for the whole test set
N = len(x_test_test)

gain_total_CNN = np.zeros(N)
gain_cum_CNN = np.zeros(N)
index_help_CNN = range(0,N)

for i in range(0, N):
  print(f'i = {i}')


  # get image from test set
  random_image = x_test_test[i]
  random_image_label = y_test_test[i]
  random_image_label_string = label_names[int(random_image_label)]

  # apply preprocessing to the image
 # random_image = flip_vertically(random_image)
 # random_image = flip_horizontally(random_image)
 # random_image = add_noise(random_image)
#  random_image = rotate_angle(random_image)

  # Convert image to tf array
  img_array = tf.keras.utils.img_to_array(random_image)
  img_array = tf.expand_dims(img_array, 0)

  # Calculate predictions
  predictions = cnn.predict(img_array)
  predicted_enemy_action = label_names[np.argmax(predictions[0])]

  gain_for_one_step = return_gain_step(predicted_enemy_action = predicted_enemy_action, actual_enemy_action = random_image_label_string)
  if i >=1:
    gain_cum_CNN[i] = gain_cum_CNN[i-1] + gain_for_one_step
  gain_total_CNN[i] = gain_for_one_step
# Out:
# i = 0
# 1/1 [==============================] - 0s 15ms/step
# i = 1
# 1/1 [==============================] - 0s 15ms/step
# i = 2
# 1/1 [==============================] - 0s 15ms/step
# i = 3
# 1/1 [==============================] - 0s 17ms/step
# i = 4
# 1/1 [==============================] - 0s 16ms/step
# i = 5
# 1/1 [==============================] - 0s 16ms/step
# i = 6
# 1/1 [==============================] - 0s 15ms/step
# i = 7
# 1/1 [==============================] - 0s 15ms/step
# i = 8
# 1/1 [==============================] - 0s 17ms/step
# i = 9
# 1/1 [==============================] - 0s 14ms/step
# i = 10
# 1/1 [==============================] - 0s 14ms/step
# i = 11
# 1/1 [==============================] - 0s 23ms/step
# i = 12
# 1/1 [==============================] - 0s 16ms/step
# i = 13
# 1/1 [==============================] - 0s 16ms/step
# i = 14
# 1/1 [==============================] - 0s 21ms/step
# i = 15
# 1/1 [==============================] - 0s 16ms/step
# i = 16
# 1/1 [==============================] - 0s 17ms/step
# i = 17
# 1/1 [==============================] - 0s 15ms/step
# i = 18
# 1/1 [==============================] - 0s 15ms/step
# i = 19
# 1/1 [==============================] - 0s 14ms/step
# i = 20
# 1/1 [==============================] - 0s 23ms/step
# i = 21
# 1/1 [==============================] - 0s 14ms/step
# i = 22
# 1/1 [==============================] - 0s 17ms/step
# i = 23
# 1/1 [==============================] - 0s 15ms/step
# i = 24
# 1/1 [==============================] - 0s 19ms/step
# i = 25
# 1/1 [==============================] - 0s 15ms/step
# i = 26
# 1/1 [==============================] - 0s 16ms/step
# i = 27
# 1/1 [==============================] - 0s 14ms/step
# i = 28
# 1/1 [==============================] - 0s 14ms/step
# i = 29
# 1/1 [==============================] - 0s 15ms/step
# i = 30
# 1/1 [==============================] - 0s 16ms/step
# i = 31
# 1/1 [==============================] - 0s 18ms/step
# i = 32
# 1/1 [==============================] - 0s 15ms/step
# i = 33
# 1/1 [==============================] - 0s 16ms/step
# i = 34
# 1/1 [==============================] - 0s 14ms/step
# i = 35
# 1/1 [==============================] - 0s 19ms/step
# i = 36
# 1/1 [==============================] - 0s 15ms/step
# i = 37
# 1/1 [==============================] - 0s 15ms/step
# i = 38
# 1/1 [==============================] - 0s 15ms/step
# i = 39
# 1/1 [==============================] - 0s 16ms/step
# i = 40
# 1/1 [==============================] - 0s 15ms/step
# i = 41
# 1/1 [==============================] - 0s 15ms/step
# i = 42
# 1/1 [==============================] - 0s 15ms/step
# i = 43
# 1/1 [==============================] - 0s 14ms/step
# i = 44
# 1/1 [==============================] - 0s 15ms/step
# i = 45
# 1/1 [==============================] - 0s 16ms/step
# i = 46
# 1/1 [==============================] - 0s 15ms/step
# i = 47
# 1/1 [==============================] - 0s 16ms/step
# i = 48
# 1/1 [==============================] - 0s 19ms/step
# i = 49
# 1/1 [==============================] - 0s 15ms/step
# i = 50
# 1/1 [==============================] - 0s 16ms/step
# i = 51
# 1/1 [==============================] - 0s 18ms/step
# i = 52
# 1/1 [==============================] - 0s 14ms/step
# i = 53
# 1/1 [==============================] - 0s 14ms/step
# i = 54
# 1/1 [==============================] - 0s 16ms/step
# i = 55
# 1/1 [==============================] - 0s 17ms/step
# i = 56
# 1/1 [==============================] - 0s 15ms/step
# i = 57
# 1/1 [==============================] - 0s 14ms/step
# i = 58
# 1/1 [==============================] - 0s 15ms/step
# i = 59
# 1/1 [==============================] - 0s 15ms/step
# i = 60
# 1/1 [==============================] - 0s 16ms/step
# i = 61
# 1/1 [==============================] - 0s 14ms/step
# i = 62
# 1/1 [==============================] - 0s 16ms/step
# i = 63
# 1/1 [==============================] - 0s 18ms/step
# i = 64
# 1/1 [==============================] - 0s 16ms/step
# i = 65
# 1/1 [==============================] - 0s 15ms/step
# i = 66
# 1/1 [==============================] - 0s 16ms/step
# i = 67
# 1/1 [==============================] - 0s 16ms/step
# i = 68
# 1/1 [==============================] - 0s 15ms/step
# i = 69
# 1/1 [==============================] - 0s 17ms/step
# i = 70
# 1/1 [==============================] - 0s 15ms/step
# i = 71
# 1/1 [==============================] - 0s 15ms/step
# i = 72
# 1/1 [==============================] - 0s 15ms/step
# i = 73
# 1/1 [==============================] - 0s 15ms/step
# i = 74
# 1/1 [==============================] - 0s 15ms/step
# i = 75
# 1/1 [==============================] - 0s 16ms/step
# i = 76
# 1/1 [==============================] - 0s 15ms/step
# i = 77
# 1/1 [==============================] - 0s 15ms/step
# i = 78
# 1/1 [==============================] - 0s 15ms/step
# i = 79
# 1/1 [==============================] - 0s 15ms/step
# i = 80
# 1/1 [==============================] - 0s 21ms/step
# i = 81
# 1/1 [==============================] - 0s 15ms/step
# i = 82
# 1/1 [==============================] - 0s 17ms/step
# i = 83
# 1/1 [==============================] - 0s 16ms/step
# i = 84
# 1/1 [==============================] - 0s 17ms/step
# i = 85
# 1/1 [==============================] - 0s 17ms/step
# i = 86
# 1/1 [==============================] - 0s 16ms/step
# i = 87
# 1/1 [==============================] - 0s 14ms/step
# i = 88
# 1/1 [==============================] - 0s 15ms/step
# i = 89
# 1/1 [==============================] - 0s 15ms/step
# i = 90
# 1/1 [==============================] - 0s 16ms/step
# i = 91
# 1/1 [==============================] - 0s 16ms/step
# i = 92
# 1/1 [==============================] - 0s 14ms/step
# i = 93
# 1/1 [==============================] - 0s 15ms/step
# i = 94
# 1/1 [==============================] - 0s 16ms/step
# i = 95
# 1/1 [==============================] - 0s 17ms/step
# i = 96
# 1/1 [==============================] - 0s 15ms/step
# i = 97
# 1/1 [==============================] - 0s 15ms/step
# i = 98
# 1/1 [==============================] - 0s 16ms/step
# i = 99
# 1/1 [==============================] - 0s 16ms/step
# i = 100
# 1/1 [==============================] - 0s 15ms/step
# i = 101
# 1/1 [==============================] - 0s 15ms/step
# i = 102
# 1/1 [==============================] - 0s 14ms/step
# i = 103
# 1/1 [==============================] - 0s 15ms/step
# i = 104
# 1/1 [==============================] - 0s 15ms/step
# i = 105
# 1/1 [==============================] - 0s 15ms/step
# i = 106
# 1/1 [==============================] - 0s 15ms/step
# i = 107
# 1/1 [==============================] - 0s 15ms/step
# i = 108
# 1/1 [==============================] - 0s 16ms/step
# i = 109
# 1/1 [==============================] - 0s 14ms/step
# i = 110
# 1/1 [==============================] - 0s 14ms/step
# i = 111
# 1/1 [==============================] - 0s 15ms/step
# i = 112
# 1/1 [==============================] - 0s 16ms/step
# i = 113
# 1/1 [==============================] - 0s 15ms/step
# i = 114
# 1/1 [==============================] - 0s 21ms/step
# i = 115
# 1/1 [==============================] - 0s 16ms/step
# i = 116
# 1/1 [==============================] - 0s 15ms/step
# i = 117
# 1/1 [==============================] - 0s 21ms/step
# i = 118
# 1/1 [==============================] - 0s 17ms/step
# i = 119
# 1/1 [==============================] - 0s 15ms/step
# i = 120
# 1/1 [==============================] - 0s 15ms/step
# i = 121
# 1/1 [==============================] - 0s 14ms/step
# i = 122
# 1/1 [==============================] - 0s 14ms/step
# i = 123
# 1/1 [==============================] - 0s 15ms/step
# i = 124
# 1/1 [==============================] - 0s 15ms/step
# i = 125
# 1/1 [==============================] - 0s 14ms/step
# i = 126
# 1/1 [==============================] - 0s 15ms/step
# i = 127
# 1/1 [==============================] - 0s 16ms/step
# i = 128
# 1/1 [==============================] - 0s 15ms/step
# i = 129
# 1/1 [==============================] - 0s 15ms/step
# i = 130
# 1/1 [==============================] - 0s 15ms/step
# i = 131
# 1/1 [==============================] - 0s 14ms/step
# i = 132
# 1/1 [==============================] - 0s 14ms/step
# i = 133
# 1/1 [==============================] - 0s 20ms/step
# i = 134
# 1/1 [==============================] - 0s 14ms/step
# i = 135
# 1/1 [==============================] - 0s 14ms/step
# i = 136
# 1/1 [==============================] - 0s 16ms/step
# i = 137
# 1/1 [==============================] - 0s 15ms/step
# i = 138
# 1/1 [==============================] - 0s 16ms/step
# i = 139
# 1/1 [==============================] - 0s 19ms/step
# i = 140
# 1/1 [==============================] - 0s 17ms/step
# i = 141
# 1/1 [==============================] - 0s 16ms/step
# i = 142
# 1/1 [==============================] - 0s 16ms/step
# i = 143
# 1/1 [==============================] - 0s 21ms/step
# i = 144
# 1/1 [==============================] - 0s 15ms/step
# i = 145
# 1/1 [==============================] - 0s 16ms/step
# i = 146
# 1/1 [==============================] - 0s 22ms/step
# i = 147
# 1/1 [==============================] - 0s 22ms/step
# i = 148
# 1/1 [==============================] - 0s 21ms/step
# i = 149
# 1/1 [==============================] - 0s 21ms/step
# i = 150
# 1/1 [==============================] - 0s 24ms/step
# i = 151
# 1/1 [==============================] - 0s 27ms/step
# i = 152
# 1/1 [==============================] - 0s 28ms/step
# i = 153
# 1/1 [==============================] - 0s 27ms/step
# i = 154
# 1/1 [==============================] - 0s 24ms/step
# i = 155
# 1/1 [==============================] - 0s 22ms/step
# i = 156
# 1/1 [==============================] - 0s 23ms/step
# i = 157
# 1/1 [==============================] - 0s 17ms/step
# i = 158
# 1/1 [==============================] - 0s 18ms/step
# i = 159
# 1/1 [==============================] - 0s 16ms/step
# i = 160
# 1/1 [==============================] - 0s 16ms/step
# i = 161
# 1/1 [==============================] - 0s 16ms/step
# i = 162
# 1/1 [==============================] - 0s 16ms/step
# i = 163
# 1/1 [==============================] - 0s 15ms/step
# i = 164
# 1/1 [==============================] - 0s 16ms/step
# i = 165
# 1/1 [==============================] - 0s 17ms/step
# i = 166
# 1/1 [==============================] - 0s 16ms/step
# i = 167
# 1/1 [==============================] - 0s 16ms/step
# i = 168
# 1/1 [==============================] - 0s 23ms/step
# i = 169
# 1/1 [==============================] - 0s 15ms/step
# i = 170
# 1/1 [==============================] - 0s 16ms/step
# i = 171
# 1/1 [==============================] - 0s 17ms/step
# i = 172
# 1/1 [==============================] - 0s 15ms/step
# i = 173
# 1/1 [==============================] - 0s 14ms/step
# i = 174
# 1/1 [==============================] - 0s 20ms/step
# i = 175
# 1/1 [==============================] - 0s 17ms/step
# i = 176
# 1/1 [==============================] - 0s 16ms/step
# i = 177
# 1/1 [==============================] - 0s 15ms/step
# i = 178
# 1/1 [==============================] - 0s 17ms/step
# i = 179
# 1/1 [==============================] - 0s 16ms/step
# i = 180
# 1/1 [==============================] - 0s 16ms/step
# i = 181
# 1/1 [==============================] - 0s 15ms/step
# i = 182
# 1/1 [==============================] - 0s 19ms/step
# i = 183
# 1/1 [==============================] - 0s 16ms/step
# i = 184
# 1/1 [==============================] - 0s 15ms/step
# i = 185
# 1/1 [==============================] - 0s 21ms/step
# i = 186
# 1/1 [==============================] - 0s 16ms/step
# i = 187
# 1/1 [==============================] - 0s 14ms/step
# i = 188
# 1/1 [==============================] - 0s 14ms/step
# i = 189
# 1/1 [==============================] - 0s 15ms/step
# i = 190
# 1/1 [==============================] - 0s 16ms/step
# i = 191
# 1/1 [==============================] - 0s 14ms/step
# i = 192
# 1/1 [==============================] - 0s 17ms/step
# i = 193
# 1/1 [==============================] - 0s 18ms/step
# i = 194
# 1/1 [==============================] - 0s 16ms/step
# i = 195
# 1/1 [==============================] - 0s 14ms/step
# i = 196
# 1/1 [==============================] - 0s 14ms/step
# i = 197
# 1/1 [==============================] - 0s 15ms/step
# i = 198
# 1/1 [==============================] - 0s 15ms/step
# i = 199
# 1/1 [==============================] - 0s 15ms/step
# i = 200
# 1/1 [==============================] - 0s 16ms/step
# i = 201
# 1/1 [==============================] - 0s 21ms/step
# i = 202
# 1/1 [==============================] - 0s 16ms/step
# i = 203
# 1/1 [==============================] - 0s 16ms/step
# i = 204
# 1/1 [==============================] - 0s 16ms/step
# i = 205
# 1/1 [==============================] - 0s 19ms/step
# i = 206
# 1/1 [==============================] - 0s 14ms/step
# i = 207
# 1/1 [==============================] - 0s 15ms/step
# i = 208
# 1/1 [==============================] - 0s 16ms/step
# i = 209
# 1/1 [==============================] - 0s 16ms/step
# i = 210
# 1/1 [==============================] - 0s 16ms/step
# i = 211
# 1/1 [==============================] - 0s 15ms/step
# i = 212
# 1/1 [==============================] - 0s 16ms/step
# i = 213
# 1/1 [==============================] - 0s 17ms/step
# i = 214
# 1/1 [==============================] - 0s 16ms/step
# i = 215
# 1/1 [==============================] - 0s 17ms/step
# i = 216
# 1/1 [==============================] - 0s 16ms/step
# i = 217
# 1/1 [==============================] - 0s 15ms/step
# i = 218
# 1/1 [==============================] - 0s 14ms/step
# i = 219
# 1/1 [==============================] - 0s 14ms/step
# i = 220
# 1/1 [==============================] - 0s 14ms/step
# i = 221
# 1/1 [==============================] - 0s 14ms/step
# i = 222
# 1/1 [==============================] - 0s 15ms/step
# i = 223
# 1/1 [==============================] - 0s 14ms/step
# i = 224
# 1/1 [==============================] - 0s 17ms/step
# i = 225
# 1/1 [==============================] - 0s 15ms/step
# i = 226
# 1/1 [==============================] - 0s 16ms/step
# i = 227
# 1/1 [==============================] - 0s 18ms/step
# i = 228
# 1/1 [==============================] - 0s 16ms/step
# i = 229
# 1/1 [==============================] - 0s 19ms/step
# i = 230
# 1/1 [==============================] - 0s 15ms/step
# i = 231
# 1/1 [==============================] - 0s 17ms/step
# i = 232
# 1/1 [==============================] - 0s 17ms/step
# i = 233
# 1/1 [==============================] - 0s 16ms/step
# i = 234
# 1/1 [==============================] - 0s 16ms/step
# i = 235
# 1/1 [==============================] - 0s 17ms/step
# i = 236
# 1/1 [==============================] - 0s 23ms/step
# i = 237
# 1/1 [==============================] - 0s 15ms/step
# i = 238
# 1/1 [==============================] - 0s 16ms/step
# i = 239
# 1/1 [==============================] - 0s 16ms/step
# i = 240
# 1/1 [==============================] - 0s 15ms/step
# i = 241
# 1/1 [==============================] - 0s 15ms/step
# i = 242
# 1/1 [==============================] - 0s 15ms/step
# i = 243
# 1/1 [==============================] - 0s 15ms/step
# i = 244
# 1/1 [==============================] - 0s 17ms/step
# i = 245
# 1/1 [==============================] - 0s 19ms/step
# i = 246
# 1/1 [==============================] - 0s 16ms/step
# i = 247
# 1/1 [==============================] - 0s 16ms/step
# i = 248
# 1/1 [==============================] - 0s 19ms/step
# i = 249
# 1/1 [==============================] - 0s 15ms/step
# i = 250
# 1/1 [==============================] - 0s 18ms/step
# i = 251
# 1/1 [==============================] - 0s 16ms/step
# i = 252
# 1/1 [==============================] - 0s 18ms/step
# i = 253
# 1/1 [==============================] - 0s 14ms/step
# i = 254
# 1/1 [==============================] - 0s 14ms/step
# i = 255
# 1/1 [==============================] - 0s 14ms/step
# i = 256
# 1/1 [==============================] - 0s 19ms/step
# i = 257
# 1/1 [==============================] - 0s 15ms/step
# i = 258
# 1/1 [==============================] - 0s 19ms/step
# i = 259
# 1/1 [==============================] - 0s 16ms/step
# i = 260
# 1/1 [==============================] - 0s 16ms/step
# i = 261
# 1/1 [==============================] - 0s 16ms/step
# i = 262
# 1/1 [==============================] - 0s 16ms/step
# i = 263
# 1/1 [==============================] - 0s 20ms/step
# i = 264
# 1/1 [==============================] - 0s 16ms/step
# i = 265
# 1/1 [==============================] - 0s 24ms/step
# i = 266
# 1/1 [==============================] - 0s 16ms/step
# i = 267
# 1/1 [==============================] - 0s 15ms/step
# i = 268
# 1/1 [==============================] - 0s 15ms/step
# i = 269
# 1/1 [==============================] - 0s 20ms/step
# i = 270
# 1/1 [==============================] - 0s 14ms/step
# i = 271
# 1/1 [==============================] - 0s 15ms/step
# i = 272
# 1/1 [==============================] - 0s 14ms/step
# i = 273
# 1/1 [==============================] - 0s 15ms/step
# i = 274
# 1/1 [==============================] - 0s 20ms/step
# i = 275
# 1/1 [==============================] - 0s 15ms/step
# i = 276
# 1/1 [==============================] - 0s 14ms/step
# i = 277
# 1/1 [==============================] - 0s 15ms/step
# i = 278
# 1/1 [==============================] - 0s 15ms/step
# i = 279
# 1/1 [==============================] - 0s 16ms/step
# i = 280
# 1/1 [==============================] - 0s 17ms/step
# i = 281
# 1/1 [==============================] - 0s 16ms/step
# i = 282
# 1/1 [==============================] - 0s 15ms/step
# i = 283
# 1/1 [==============================] - 0s 15ms/step
# i = 284
# 1/1 [==============================] - 0s 15ms/step
# i = 285
# 1/1 [==============================] - 0s 16ms/step
# i = 286
# 1/1 [==============================] - 0s 14ms/step
# i = 287
# 1/1 [==============================] - 0s 17ms/step
# i = 288
# 1/1 [==============================] - 0s 15ms/step
# i = 289
# 1/1 [==============================] - 0s 14ms/step
# i = 290
# 1/1 [==============================] - 0s 15ms/step
# i = 291
# 1/1 [==============================] - 0s 16ms/step
# i = 292
# 1/1 [==============================] - 0s 16ms/step
# i = 293
# 1/1 [==============================] - 0s 14ms/step
# i = 294
# 1/1 [==============================] - 0s 16ms/step
# i = 295
# 1/1 [==============================] - 0s 17ms/step
# i = 296
# 1/1 [==============================] - 0s 16ms/step
# i = 297
# 1/1 [==============================] - 0s 14ms/step
# i = 298
# 1/1 [==============================] - 0s 16ms/step
# i = 299
# 1/1 [==============================] - 0s 15ms/step
# i = 300
# 1/1 [==============================] - 0s 17ms/step
# i = 301
# 1/1 [==============================] - 0s 17ms/step
# i = 302
# 1/1 [==============================] - 0s 16ms/step
# i = 303
# 1/1 [==============================] - 0s 15ms/step
# i = 304
# 1/1 [==============================] - 0s 16ms/step
# i = 305
# 1/1 [==============================] - 0s 15ms/step
# i = 306
# 1/1 [==============================] - 0s 15ms/step
# i = 307
# 1/1 [==============================] - 0s 16ms/step
# i = 308
# 1/1 [==============================] - 0s 19ms/step
# i = 309
# 1/1 [==============================] - 0s 17ms/step
# i = 310
# 1/1 [==============================] - 0s 15ms/step
# i = 311
# 1/1 [==============================] - 0s 16ms/step
# i = 312
# 1/1 [==============================] - 0s 15ms/step
# i = 313
# 1/1 [==============================] - 0s 15ms/step
# i = 314
# 1/1 [==============================] - 0s 19ms/step
# i = 315
# 1/1 [==============================] - 0s 15ms/step
# i = 316
# 1/1 [==============================] - 0s 15ms/step
# i = 317
# 1/1 [==============================] - 0s 15ms/step
# i = 318
# 1/1 [==============================] - 0s 18ms/step
# i = 319
# 1/1 [==============================] - 0s 16ms/step
# i = 320
# 1/1 [==============================] - 0s 17ms/step
# i = 321
# 1/1 [==============================] - 0s 18ms/step
# i = 322
# 1/1 [==============================] - 0s 16ms/step
# i = 323
# 1/1 [==============================] - 0s 14ms/step
# i = 324
# 1/1 [==============================] - 0s 25ms/step
# i = 325
# 1/1 [==============================] - 0s 26ms/step
# i = 326
# 1/1 [==============================] - 0s 26ms/step
# i = 327
# 1/1 [==============================] - 0s 20ms/step
# i = 328
# 1/1 [==============================] - 0s 19ms/step
# i = 329
# 1/1 [==============================] - 0s 19ms/step
# i = 330
# 1/1 [==============================] - 0s 19ms/step
# i = 331
# 1/1 [==============================] - 0s 22ms/step
# i = 332
# 1/1 [==============================] - 0s 24ms/step
# i = 333
# 1/1 [==============================] - 0s 20ms/step
# i = 334
# 1/1 [==============================] - 0s 25ms/step
# i = 335
# 1/1 [==============================] - 0s 23ms/step
# i = 336
# 1/1 [==============================] - 0s 15ms/step
# i = 337
# 1/1 [==============================] - 0s 15ms/step
# i = 338
# 1/1 [==============================] - 0s 15ms/step
# i = 339
# 1/1 [==============================] - 0s 17ms/step
# i = 340
# 1/1 [==============================] - 0s 17ms/step
# i = 341
# 1/1 [==============================] - 0s 15ms/step
# i = 342
# 1/1 [==============================] - 0s 16ms/step
# i = 343
# 1/1 [==============================] - 0s 15ms/step
# i = 344
# 1/1 [==============================] - 0s 14ms/step
# i = 345
# 1/1 [==============================] - 0s 17ms/step
# i = 346
# 1/1 [==============================] - 0s 15ms/step
# i = 347
# 1/1 [==============================] - 0s 15ms/step
# i = 348
# 1/1 [==============================] - 0s 16ms/step
# i = 349
# 1/1 [==============================] - 0s 15ms/step
# i = 350
# 1/1 [==============================] - 0s 19ms/step
# i = 351
# 1/1 [==============================] - 0s 17ms/step
# i = 352
# 1/1 [==============================] - 0s 15ms/step
# i = 353
# 1/1 [==============================] - 0s 14ms/step
# i = 354
# 1/1 [==============================] - 0s 15ms/step
# i = 355
# 1/1 [==============================] - 0s 15ms/step
# i = 356
# 1/1 [==============================] - 0s 16ms/step
# i = 357
# 1/1 [==============================] - 0s 17ms/step
# i = 358
# 1/1 [==============================] - 0s 16ms/step
# i = 359
# 1/1 [==============================] - 0s 16ms/step
# i = 360
# 1/1 [==============================] - 0s 14ms/step
# i = 361
# 1/1 [==============================] - 0s 17ms/step
# i = 362
# 1/1 [==============================] - 0s 15ms/step
# i = 363
# 1/1 [==============================] - 0s 15ms/step
# i = 364
# 1/1 [==============================] - 0s 16ms/step
# i = 365
# 1/1 [==============================] - 0s 16ms/step
# i = 366
# 1/1 [==============================] - 0s 15ms/step
# i = 367
# 1/1 [==============================] - 0s 15ms/step
# i = 368
# 1/1 [==============================] - 0s 16ms/step
# i = 369
# 1/1 [==============================] - 0s 16ms/step
# i = 370
# 1/1 [==============================] - 0s 19ms/step
# i = 371
# 1/1 [==============================] - 0s 15ms/step
# i = 372
# 1/1 [==============================] - 0s 15ms/step
# i = 373
# 1/1 [==============================] - 0s 15ms/step
# i = 374
# 1/1 [==============================] - 0s 16ms/step
# i = 375
# 1/1 [==============================] - 0s 15ms/step
# i = 376
# 1/1 [==============================] - 0s 17ms/step
# i = 377
# 1/1 [==============================] - 0s 15ms/step
# i = 378
# 1/1 [==============================] - 0s 15ms/step
# i = 379
# 1/1 [==============================] - 0s 14ms/step
# i = 380
# 1/1 [==============================] - 0s 16ms/step
# i = 381
# 1/1 [==============================] - 0s 16ms/step
# i = 382
# 1/1 [==============================] - 0s 15ms/step
# i = 383
# 1/1 [==============================] - 0s 15ms/step
# i = 384
# 1/1 [==============================] - 0s 15ms/step
# i = 385
# 1/1 [==============================] - 0s 15ms/step
# i = 386
# 1/1 [==============================] - 0s 16ms/step
# i = 387
# 1/1 [==============================] - 0s 15ms/step
# i = 388
# 1/1 [==============================] - 0s 14ms/step
# i = 389
# 1/1 [==============================] - 0s 16ms/step
# i = 390
# 1/1 [==============================] - 0s 15ms/step
# i = 391
# 1/1 [==============================] - 0s 15ms/step
# i = 392
# 1/1 [==============================] - 0s 16ms/step
# i = 393
# 1/1 [==============================] - 0s 17ms/step
# i = 394
# 1/1 [==============================] - 0s 18ms/step
# i = 395
# 1/1 [==============================] - 0s 18ms/step
# i = 396
# 1/1 [==============================] - 0s 14ms/step
# i = 397
# 1/1 [==============================] - 0s 15ms/step
# i = 398
# 1/1 [==============================] - 0s 17ms/step
# i = 399
# 1/1 [==============================] - 0s 14ms/step
# i = 400
# 1/1 [==============================] - 0s 22ms/step
# i = 401
# 1/1 [==============================] - 0s 15ms/step
# i = 402
# 1/1 [==============================] - 0s 16ms/step
# i = 403
# 1/1 [==============================] - 0s 15ms/step
# i = 404
# 1/1 [==============================] - 0s 18ms/step
# i = 405
# 1/1 [==============================] - 0s 16ms/step
# i = 406
# 1/1 [==============================] - 0s 15ms/step
# i = 407
# 1/1 [==============================] - 0s 16ms/step
# i = 408
# 1/1 [==============================] - 0s 16ms/step
# i = 409
# 1/1 [==============================] - 0s 16ms/step
# i = 410
# 1/1 [==============================] - 0s 14ms/step
# i = 411
# 1/1 [==============================] - 0s 15ms/step
# i = 412
# 1/1 [==============================] - 0s 14ms/step
# i = 413
# 1/1 [==============================] - 0s 15ms/step
# i = 414
# 1/1 [==============================] - 0s 19ms/step
# i = 415
# 1/1 [==============================] - 0s 16ms/step
# i = 416
# 1/1 [==============================] - 0s 15ms/step
# i = 417
# 1/1 [==============================] - 0s 19ms/step
# i = 418
# 1/1 [==============================] - 0s 14ms/step
# i = 419
# 1/1 [==============================] - 0s 14ms/step
# i = 420
# 1/1 [==============================] - 0s 15ms/step
# i = 421
# 1/1 [==============================] - 0s 15ms/step
# i = 422
# 1/1 [==============================] - 0s 14ms/step
# i = 423
# 1/1 [==============================] - 0s 15ms/step
# i = 424
# 1/1 [==============================] - 0s 14ms/step
# i = 425
# 1/1 [==============================] - 0s 15ms/step
# i = 426
# 1/1 [==============================] - 0s 15ms/step
# i = 427
# 1/1 [==============================] - 0s 15ms/step
# i = 428
# 1/1 [==============================] - 0s 17ms/step
# i = 429
# 1/1 [==============================] - 0s 14ms/step
# i = 430
# 1/1 [==============================] - 0s 16ms/step
# i = 431
# 1/1 [==============================] - 0s 16ms/step
# i = 432
# 1/1 [==============================] - 0s 16ms/step
# i = 433
# 1/1 [==============================] - 0s 15ms/step
# i = 434
# 1/1 [==============================] - 0s 20ms/step
# i = 435
# 1/1 [==============================] - 0s 16ms/step
# i = 436
# 1/1 [==============================] - 0s 15ms/step
# i = 437
# 1/1 [==============================] - 0s 14ms/step
# i = 438
# 1/1 [==============================] - 0s 16ms/step
# i = 439
# 1/1 [==============================] - 0s 15ms/step
# i = 440
# 1/1 [==============================] - 0s 15ms/step
# i = 441
# 1/1 [==============================] - 0s 15ms/step
# i = 442
# 1/1 [==============================] - 0s 16ms/step
# i = 443
# 1/1 [==============================] - 0s 15ms/step
# i = 444
# 1/1 [==============================] - 0s 18ms/step
# i = 445
# 1/1 [==============================] - 0s 14ms/step
# i = 446
# 1/1 [==============================] - 0s 14ms/step
# i = 447
# 1/1 [==============================] - 0s 15ms/step
# i = 448
# 1/1 [==============================] - 0s 15ms/step
# i = 449
# 1/1 [==============================] - 0s 15ms/step
# i = 450
# 1/1 [==============================] - 0s 14ms/step
# i = 451
# 1/1 [==============================] - 0s 15ms/step
# i = 452
# 1/1 [==============================] - 0s 15ms/step
# i = 453
# 1/1 [==============================] - 0s 17ms/step
# i = 454
# 1/1 [==============================] - 0s 14ms/step
# i = 455
# 1/1 [==============================] - 0s 16ms/step
# i = 456
# 1/1 [==============================] - 0s 14ms/step
# i = 457
# 1/1 [==============================] - 0s 15ms/step
# i = 458
# 1/1 [==============================] - 0s 17ms/step
# i = 459
# 1/1 [==============================] - 0s 17ms/step
# i = 460
# 1/1 [==============================] - 0s 16ms/step
# i = 461
# 1/1 [==============================] - 0s 17ms/step
# i = 462
# 1/1 [==============================] - 0s 15ms/step
# i = 463
# 1/1 [==============================] - 0s 15ms/step
# i = 464
# 1/1 [==============================] - 0s 15ms/step
# i = 465
# 1/1 [==============================] - 0s 16ms/step
# i = 466
# 1/1 [==============================] - 0s 15ms/step
# i = 467
# 1/1 [==============================] - 0s 19ms/step
# i = 468
# 1/1 [==============================] - 0s 15ms/step
# i = 469
# 1/1 [==============================] - 0s 14ms/step
# i = 470
# 1/1 [==============================] - 0s 14ms/step
# i = 471
# 1/1 [==============================] - 0s 15ms/step
# i = 472
# 1/1 [==============================] - 0s 14ms/step
# i = 473
# 1/1 [==============================] - 0s 15ms/step
# i = 474
# 1/1 [==============================] - 0s 16ms/step
# i = 475
# 1/1 [==============================] - 0s 15ms/step
# i = 476
# 1/1 [==============================] - 0s 16ms/step
# i = 477
# 1/1 [==============================] - 0s 16ms/step
# i = 478
# 1/1 [==============================] - 0s 16ms/step
# i = 479
# 1/1 [==============================] - 0s 15ms/step
# i = 480
# 1/1 [==============================] - 0s 18ms/step
# i = 481
# 1/1 [==============================] - 0s 15ms/step
# i = 482
# 1/1 [==============================] - 0s 15ms/step
# i = 483
# 1/1 [==============================] - 0s 16ms/step
# i = 484
# 1/1 [==============================] - 0s 15ms/step
# i = 485
# 1/1 [==============================] - 0s 16ms/step
# i = 486
# 1/1 [==============================] - 0s 15ms/step
# i = 487
# 1/1 [==============================] - 0s 15ms/step
# i = 488
# 1/1 [==============================] - 0s 18ms/step
# i = 489
# 1/1 [==============================] - 0s 15ms/step
# i = 490
# 1/1 [==============================] - 0s 17ms/step
# i = 491
# 1/1 [==============================] - 0s 16ms/step
# i = 492
# 1/1 [==============================] - 0s 16ms/step
# i = 493
# 1/1 [==============================] - 0s 16ms/step
# i = 494
# 1/1 [==============================] - 0s 15ms/step
# i = 495
# 1/1 [==============================] - 0s 16ms/step
# i = 496
# 1/1 [==============================] - 0s 18ms/step
# i = 497
# 1/1 [==============================] - 0s 16ms/step
# i = 498
# 1/1 [==============================] - 0s 15ms/step
# i = 499
# 1/1 [==============================] - 0s 15ms/step
# i = 500
# 1/1 [==============================] - 0s 17ms/step
# i = 501
# 1/1 [==============================] - 0s 29ms/step
# i = 502
# 1/1 [==============================] - 0s 20ms/step
# i = 503
# 1/1 [==============================] - 0s 23ms/step
# i = 504
# 1/1 [==============================] - 0s 22ms/step
# i = 505
# 1/1 [==============================] - 0s 22ms/step
# i = 506
# 1/1 [==============================] - 0s 20ms/step
# i = 507
# 1/1 [==============================] - 0s 23ms/step
# i = 508
# 1/1 [==============================] - 0s 24ms/step
# i = 509
# 1/1 [==============================] - 0s 22ms/step
# i = 510
# 1/1 [==============================] - 0s 19ms/step
# i = 511
# 1/1 [==============================] - 0s 21ms/step
# i = 512
# 1/1 [==============================] - 0s 23ms/step
# i = 513
# 1/1 [==============================] - 0s 17ms/step
# i = 514
# 1/1 [==============================] - 0s 19ms/step
# i = 515
# 1/1 [==============================] - 0s 15ms/step
# i = 516
# 1/1 [==============================] - 0s 16ms/step
# i = 517
# 1/1 [==============================] - 0s 19ms/step
# i = 518
# 1/1 [==============================] - 0s 17ms/step
# i = 519
# 1/1 [==============================] - 0s 17ms/step
# i = 520
# 1/1 [==============================] - 0s 15ms/step
# i = 521
# 1/1 [==============================] - 0s 15ms/step
# i = 522
# 1/1 [==============================] - 0s 17ms/step
# i = 523
# 1/1 [==============================] - 0s 17ms/step
# i = 524
# 1/1 [==============================] - 0s 14ms/step
# i = 525
# 1/1 [==============================] - 0s 15ms/step
# i = 526
# 1/1 [==============================] - 0s 14ms/step
# i = 527
# 1/1 [==============================] - 0s 15ms/step
# i = 528
# 1/1 [==============================] - 0s 16ms/step
# i = 529
# 1/1 [==============================] - 0s 14ms/step
# i = 530
# 1/1 [==============================] - 0s 15ms/step
# i = 531
# 1/1 [==============================] - 0s 16ms/step
# i = 532
# 1/1 [==============================] - 0s 14ms/step
# i = 533
# 1/1 [==============================] - 0s 17ms/step
# i = 534
# 1/1 [==============================] - 0s 15ms/step
# i = 535
# 1/1 [==============================] - 0s 14ms/step
# i = 536
# 1/1 [==============================] - 0s 15ms/step
# i = 537
# 1/1 [==============================] - 0s 15ms/step
# i = 538
# 1/1 [==============================] - 0s 15ms/step
# i = 539
# 1/1 [==============================] - 0s 14ms/step

# %%
plt.plot(index_help, gain_cum)
plt.xlabel('Ascending Number (Sample index)')
plt.ylabel('Cumulative Gain')
plt.title('Cumulative gain vs Sample Index')
# Out:
# Text(0.5, 1.0, 'Cumulative gain vs Sample Index')

# %%
# As accuracy, I will define how many time the agent won (so gain is 2), over how many times the agent played
unique, counts = np.unique(gain_total, return_counts=True)
print(f'The unique values are: {unique}')
print(f'The count values are:  {counts}')
print(f'Accuracy is counts[2]/sum(counts) * 100% = {counts[2]/sum(counts)*100:.2f}%')
# Out:
# The unique values are: [0. 1. 2.]
# The count values are:  [ 52  86 225]
# Accuracy is counts[2]/sum(counts) * 100% = 61.98%

# %%
x_test_test_cnn = np.reshape(x_test_test_flatten_norm, (x_test_test_flatten_norm.shape[0], dim1,dim2,1))
print(x_test_test_cnn.shape)

cnn_test_loss, cnn_test_acc = cnn.evaluate(x_test_test_cnn, y_test_test_tf, verbose=2)
print('')
print(f'Our CNN has achieved a test accuracy of {cnn_test_acc*100:.2f}%')
# Out:
# (540, 20, 30, 1)
# 17/17 - 0s - loss: 6.1026 - accuracy: 0.3556 - 118ms/epoch - 7ms/step
#
# Our CNN has achieved a test accuracy of 35.56%

# %% [markdown]
# Not sure why the 2 ways of calculating accuracy did not give the same value...

# %% [markdown]
# ## We notice that our model did not do as good, in these test data. Still, the images were harder than our train set. The train set was clear rock/paper/scissors images, with green background.

# %% [markdown]
# When doing all the pre-processing steps, we have:
#
# * The unique values are: [0. 1. 2.]
# * The count values are:  [163 180 197]
# * Accuracy is counts[2]/sum(counts) * 100% = 36.48%

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# I tried without the 4th pre-processings tep (the rotation), but the results did not seem to improve:
# * The unique values are: [0. 1. 2.]
# * The count values are:  [181 173 186]
# * Accuracy is counts[2]/sum(counts) * 100% = 34.44%

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# I tried while having kept only the add-noise pre-processings step, and these are the results:
# * The unique values are: [0. 1. 2.]
# * The count values are:  [180 170 190]
# * Accuracy is counts[2]/sum(counts) * 100% = 35.19%

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# I also tried without any pre-processing, and these are the results:
# * The unique values are: [0. 1. 2.]
# * The count values are:  [177 159 204]
# * Accuracy is counts[2]/sum(counts) * 100% = 37.78%

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Maybe the reason I am not getting good accuracy in the new test set, is because of image dimensions. Truly, I inspected the new images, and they are 300x300, so making them into 20x30 is distorting the images.
# ## Generally speaking, CNN are the go-to choice for image classification, and we achieved 97.52% accuracy with them. Still, I will also try some more sklearn methods, to see what accuracy they yield.

# %% [markdown]
# # Let's also try doing this with an SVM

# %%
from sklearn import svm
from sklearn.svm import LinearSVC

# %%
# I define our SVM model, then train it
model_SVM = svm.SVC()
#model_SVM = LinearSVC(dual="auto", random_state=0, tol=1e-5)
model_SVM.fit(x_train_flatten, y_train)

#
preds_SVM = model_SVM.predict(x_test_flatten)
acc_SVM = accuracy_score(preds_SVM, y_test)
print(f'SVM accuracy in the test set: {acc_SVM}')
# Out:
# SVM accuracy in the test set: 0.90633608815427

# %%
# i will now try calculating the total gain for the whole test set
N = len(x_test)

gain_total = np.zeros(N)
gain_cum = np.zeros(N)
index_help = range(0,N)

for i in range(0, N):
 # print(f'i = {i}')


  # get image from test set
  random_image = x_test[i]
  random_image_label = y_test[i]
  random_image_label_string = label_names[int(random_image_label)]

  # apply preprocessing to the image
  random_image = flip_vertically(random_image)
  random_image = flip_horizontally(random_image)
  random_image = add_noise(random_image)
  random_image = rotate_angle(random_image)

  random_image_flatten = random_image.reshape(1, -1)

  # Calculate predictions
  predictions = model_SVM.predict(random_image_flatten)
  predicted_enemy_action = label_names[np.argmax(predictions[0])]

  gain_for_one_step = return_gain_step(predicted_enemy_action = predicted_enemy_action, actual_enemy_action = random_image_label_string)
  if i >=1:
    gain_cum[i] = gain_cum[i-1] + gain_for_one_step
  gain_total[i] = gain_for_one_step

# %%
plt.plot(index_help, gain_cum)
plt.xlabel('Ascending Number (Sample index)')
plt.ylabel('Cumulative Gain')
plt.title('Cumulative gain vs Sample Index')
# Out:
# Text(0.5, 1.0, 'Cumulative gain vs Sample Index')

# %%
# As accuracy, I will define how many time the agent won (so gain is 2), over how many times the agent played
unique, counts = np.unique(gain_total, return_counts=True)
print(f'The unique values are: {unique}')
print(f'The count values are:  {counts}')
print(f'Accuracy is counts[2]/sum(counts) * 100% = {counts[2]/sum(counts)*100:.2f}%')
# Out:
# The unique values are: [0. 1. 2.]
# The count values are:  [ 74 143 146]
# Accuracy is counts[2]/sum(counts) * 100% = 40.22%

# %% [markdown]
# The results here, for all 4 pre-processing steps, are:
# * The unique values are: [0. 1. 2.]
# * The count values are:  [ 74 143 146]
# * Accuracy is counts[2]/sum(counts) * 100% = 40.22%

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The results, when skipping the 4th pre-processing step, are:
# * The unique values are: [0. 1. 2.]
# * The count values are:  [ 74 143 146]
# * Accuracy is counts[2]/sum(counts) * 100% = 40.22%

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Also same results if we only keep the noise pre-processing step, and if we use no pre-processing. These resuslts, and the fact that accuracy when predicting in the test set was 90% is not a good sign, since I would expect these 2 ways of counting accuracy to match.

# %% [markdown]
# # Let's also try more sklearn models

# %%
from sklearn.neural_network import MLPClassifier

# %%
# I define our NN model, then train it
model_NN = MLPClassifier(random_state=0, max_iter=300)
model_NN.fit(x_train_flatten, y_train)

#
preds_NN = model_NN.predict(x_test_flatten)
acc_NN = accuracy_score(preds_NN, y_test)
print(f'NN accuracy in the test set: {acc_NN}')
# Out:
# NN accuracy in the test set: 0.7658402203856749

# %%
from sklearn.neighbors import NearestNeighbors

# %%
# I define our NN model, then train it
model_kNN = KNeighborsClassifier()
model_kNN.fit(x_train_flatten, y_train)

#

preds_kNN = model_kNN.predict(x_test_flatten)
acc_kNN = accuracy_score(preds_kNN, y_test)
print(f'kNN accuracy in the test set: {acc_kNN}')
# Out:
# kNN accuracy in the test set: 0.8953168044077136

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model_RF = RandomForestClassifier(max_depth=2, random_state=0)
model_RF.fit(x_train_flatten, y_train)

#

preds_RF = model_RF.predict(x_test_flatten)
acc_RF = accuracy_score(preds_RF, y_test)
print(f'RF accuracy in the test set: {acc_RF}')
# Out:
# RF accuracy in the test set: 0.696969696969697

# %% [markdown]
# # **RESULT:**
# * Our CNN model achieved accuracy $\cong$ 97.52 %
# * Some sklearn models that I tried (SVM, NN, kNN, RF) had accuracy:
#   * 90.63 % (SVM)
#   * 76.58 % (NN)
#   * 89.53 % (kNN)
#   * 69.69 % (RF).

# %% [markdown]
# # 3. In which images dose our model work, and in which images does it not?

# %% [markdown]
# * I observed that the test accuracy after the initial training was quite high (97.5 %). Thus, our model did exceptionally good at classifying the initial images (clear rock/paper/scissors images, in monochrome green background).
# * The test accuracy was not good in the test set of another dataset (https://www.kaggle.com/datasets/glushko/rock-paper-scissors-dataset). This dataset did not have clear rock/paper/scissors images, but also had faces and other objects in the images, and the background was not monochrome.
# * I opted for using CNN, since I know that they perform well in image recognition, and that's why the test set accuracy was so high. Still, in the external test set, the accuracy was not good (the keras method gave 33%, and my manual method 57%)
# * I notice how the other models that I tried had lower accuracy in the initial test set, so they would have even lower in the external test set.

# %% [markdown]
# # If we have time, we could also try doing it with reinforcement learning (with an agent)

# %% [markdown]
# # 5. Create an agent. Use summart to print the policy model. Describe the created Neural Network.

# %%
def import_agent():
  import gymnasium as gym
  import ray
  from ray.rllib.algorithms.ppo import PPOConfig
#import_agent()

# %%
def agent_definition_01():
  ray.shutdown()
  ray.init()

  config = PPOConfig()
  config.use_critic = True # Use Actor-Critic Architecture
  config.use_gae = True # Use Generalzed Advantage Updates
  config.lambda_ = 0.95 # Lambda Learning parameter
  config.user_kl_loss = True # Use KL-Penalty in addition to e-Clipping
  config.sgd_minibatch_size = 32 # Batch Size
  config.num_sgd_iter = 30 # Epochs
  config.shuffle_sequences = True # Whether to shffle episode sequences
  config.vf_loss_coeff = 0.5 # Value Function loss Regularization
  config.entropy_coeff = 0.001 # Entropy Regularization coefficient for Exploration
  config.clip_param = 0.2 # e-Clipping parameter

  agent = config.environment("LunarLander-v2").framework(framework='tf').build()
  agent.get_policy().model.base_model.summary(expand_nested=True)
#agent_definition_01()

# %% [markdown]
# # 6. Create a train loop to train the agent

# %%
def agent_train():
  train_iterations = 100
  average_rewards_per_iteration = []

  for i in range(train_iterations):
    log = agent.train()
    average_rewards = log['sampler_results']['episode_reward_mean']
    average_rewards_per_iteration.append(average_rewards)

    print(f'Iteration {i + 1}, Average Rewards: {average_rewards}')


  plt.plot(average_rewards_per_iteration)
  plt.title('PPO LunarLander-v2')
  plt.xlabel('Iterations')
  plt.ylabel('Average Rewards')
  plt.show()
#agent_train()

# %% [markdown]
# # 7. Use the library renderlab to "render" the gym environmonet in colab, to see how the trained agent plays.

# %%
#import renderlab as rl

# %%
def agent_run():
  env = gym.make("LunarLander-v2", render_mode = "rgb_array")
  env = rl.RenderFrame(env, "./output")

  observation, info = env.reset()

  while True:
    action = env.action_space.sample()
    observation,reward, terminated, truncated, info = env.step(action)

    if terminated or truncated:
      break

  env.play()
#agent_run()
